# %% [markdown]
# # Fetch data about sensors and current polution level

# %%
import requests

headers = {
    'Accept': 'application/json',
    'apikey': '***',
}

#rybnik's geographical coordinates
params = (
    ('southwestLat', '50.033'),
    ('southwestLong', '18.428'),
    ('northeastLat', '50.180'),
    ('northeastLong', '18.662'),
)

response = requests.get('https://airapi.airly.eu/v1/sensors/current', headers=headers, params=params)

# %%
data_js = response.json()

# %% [markdown]
# ## Convert json to dataframe

# %%
#only official rybnik's sensors
df_temp = pd.DataFrame.from_records(data_js).query("name == 'Rybnik' and vendor == 'Airly'")

#unfold address dict
df_temp = pd.concat([df_temp.drop(['address'], axis=1), df_temp['address'].apply(pd.Series)], axis=1)
#unfold location dict
sensors = pd.concat([df_temp.drop(['location'], axis=1), df_temp['location'].apply(pd.Series)], axis=1).reset_index(drop=True)

# %%
sensors
# Out:
#       id    name  pollutionLevel vendor country  \
# 0   2083  Rybnik               3  Airly  Poland
# 1   2091  Rybnik               3  Airly  Poland
# 2   2094  Rybnik               4  Airly  Poland
# 3   2107  Rybnik               4  Airly  Poland
# 4   2174  Rybnik               3  Airly  Poland
# 5   2198  Rybnik               3  Airly  Poland
# 6   2202  Rybnik               3  Airly  Poland
# 7   2206  Rybnik               4  Airly  Poland
# 8   2211  Rybnik               3  Airly  Poland
# 9   2331  Rybnik               4  Airly  Poland
# 10  2095  Rybnik               4  Airly  Poland
# 11  2110  Rybnik               4  Airly  Poland
# 12  2243  Rybnik               4  Airly  Poland
# 13  2250  Rybnik               3  Airly  Poland
# 14  2269  Rybnik               3  Airly  Poland
# 15  2273  Rybnik               4  Airly  Poland
# 16  2297  Rybnik               4  Airly  Poland
# 17  2301  Rybnik               3  Airly  Poland
# 18  2303  Rybnik               4  Airly  Poland
# 19  2312  Rybnik               3  Airly  Poland
# 20  2324  Rybnik               4  Airly  Poland
# 21  2328  Rybnik               4  Airly  Poland
# 22  2329  Rybnik               4  Airly  Poland
# 23  2333  Rybnik               3  Airly  Poland
# 24  2341  Rybnik               4  Airly  Poland
# 25  2348  Rybnik               3  Airly  Poland
# 26  2359  Rybnik               3  Airly  Poland
#
#                          locality                          route streetNumber  \
# 0              Rybnik, Chwałęcice                      Gzelska 7       ZSP 15
# 1           Rybnik, Maroko-Nowiny                Orzepowicka 15a         ZS 3
# 2                  Rybnik, Smolna                 W. Reymonta 69        SP 34
# 3             Rybnik, Śródmieście                T. Kościuszki 5          ZST
# 4                 Rybnik, Golejów  Komisji Edukacji Narodowej 29        ZSP 4
# 5                 Rybnik, Ochojec                  B. Kuglera 8a        ZSP 3
# 6      Rybnik, Paruszowiec-Piaski                       Wolna 17         SP 3
# 7               Rybnik, Niewiadom                    Sportowa 52        SP 23
# 8     Rybnik, Boguszowice Osiedle                     J. Lompy 6        ZSP 8
# 9              Rybnik, Orzepowice                      Borki 37D        ZSP 7
# 10             Rybnik, Chwałowice                  J. 1 Maja 91a         LO 4
# 11               Rybnik, Zamysłów               Wodzisławska 123        ZSP 9
# 12              Rybnik, Wielopole                   Gliwicka 105        ZSP 1
# 13           Rybnik, Zebrzydowice                     M. Buhla 3       ZSP 12
# 14                Rybnik, Stodoły                   Zwonowicka 5          OSP
# 15              Rybnik, Radziejów                       Kręta 20        SP 24
# 16            Rybnik, Gotartowice                Gotartowicka 24         P 22
# 17        Rybnik, Rybnicka Kuźnia            Św. Maksymiliana 26       ZSP 13
# 18          Rybnik, Rybnik-Północ         dr. M. Różańskiego 14a        ZSP 5
# 19                 Rybnik, Kamień                 A. Szewczyka 6        SP 28
# 20      Rybnik, Boguszowice Stare           S. Małachowskiego 44        ZSP 6
# 21  Rybnik, Ligota-Ligocka Kuźnia                   K. Miarki 74         SP 4
# 22            Rybnik, Niedobczyce               Niedobczycka 191        SP 21
# 23                 Rybnik, Meksyk                Świerklańska 42          ZSB
# 24               Rybnik, Popielów                   L.Staffa 42a       ZSP 14
# 25               Rybnik, Kłokocin                Włościańska 39e        SP 19
# 26              Rybnik, Grabownia                W. Poloczka 76c          OSP
#
#      latitude  longitude
# 0   50.133136  18.485427
# 1   50.100009  18.517341
# 2   50.090576  18.526136
# 3   50.096996  18.549377
# 4   50.143863  18.540533
# 5   50.164684  18.546913
# 6   50.096382  18.583908
# 7   50.074623  18.465013
# 8   50.048667  18.605903
# 9   50.110969  18.516067
# 10  50.069202  18.548221
# 11  50.081203  18.526903
# 12  50.122707  18.550050
# 13  50.101856  18.492540
# 14  50.154125  18.477291
# 15  50.054557  18.525049
# 16  50.075141  18.615943
# 17  50.124736  18.525684
# 18  50.103034  18.551485
# 19  50.139717  18.603401
# 20  50.061119  18.599267
# 21  50.089809  18.578859
# 22  50.070331  18.501020
# 23  50.083858  18.553703
# 24  50.053859  18.512569
# 25  50.054828  18.626314
# 26  50.140670  18.523370
